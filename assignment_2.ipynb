# %%
import numpy as np

# %%
# Question 1

# %%
arr = np.random.rand(10, 1) # Creating numpy array of shape (10, 1)
np.mean(arr) # Calculating mean of a numpy array
# Out:
# 0.4018993864144525

# %%
# Question 2

# %%
arr = np.random.rand(20, 1) # Creating numpy array of shape (20, 1)
print("Variance : ", np.var(arr)) # Calculating variance
print("Standard Deviation : ", np.std(arr)) # Calculating standard deviation
# Out:
# Variance :  0.06517800145623578
# Standard Deviation :  0.25529982658873035

# %%
# Question 3

# %%
A = np.random.rand(10, 20)
B = np.random.rand(20, 25)
new_mat = A @ B # Matrix multiplication
print(new_mat.shape)
print (new_mat)
print("Sum : ", np.sum(new_mat))
# Out:
# (10, 25)
# [[5.32630182 4.48968326 4.09002091 3.90687041 3.98330777 6.36194595
#   5.46081014 5.37123852 5.45545505 3.57794897 5.09807554 5.68081017
#   3.30331244 6.29585437 5.55647483 4.76560702 4.89796592 5.34527364
#   4.38998424 5.20711154 3.54066358 5.10186478 5.07868643 4.87935481
#   5.62874619]
#  [5.26267676 4.56204387 3.37220292 3.36521267 3.22771625 4.50296756
#   5.01752711 5.46015118 4.87189317 3.18717669 3.96230534 5.31566939
#   3.61317812 5.65021172 5.03974847 4.31194884 4.97275085 4.90964772
#   4.10451456 5.09144944 3.72370513 5.1637307  4.492107   4.73838333
#   5.20407802]
#  [5.2150491  4.655706   4.41265144 3.62727125 4.16824485 5.28248108
#   5.62086973 5.7850086  5.27675821 3.67397214 4.62122106 5.58377954
#   3.79140168 6.1837497  4.91383245 4.72562387 5.28949643 5.34674109
#   4.66104501 5.87236248 4.83822456 5.7496759  4.66814647 5.28424073
#   5.75268643]
#  [4.61854961 3.99908698 3.73990943 3.67592925 3.49367626 5.79386497
# ...

# %%
# Question 4

# %%
arr = np.random.rand(10, 1)

# %%
n = np.array(list(map(lambda x: 1 / (1 + np.exp(-x)) , arr)))
print(n)
# Out:
# [[0.65889608]
#  [0.61761016]
#  [0.66894335]
#  [0.70034023]
#  [0.708272  ]
#  [0.70830766]
#  [0.53774681]
#  [0.64843546]
#  [0.66263267]
#  [0.67257965]]
